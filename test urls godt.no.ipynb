# %%
# example url: https://www.godt.no/oppskrift/8900

#want to check for recipees stored from oppskrift 5000 to 9999

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
url = 'https://www.godt.no/oppskrift/8900'
page = requests.get(url)
soup = BeautifulSoup(page.content, "html.parser")

# %%
df = pd.DataFrame(index=range(4999),columns=range(3))
df[0] = 'https://www.godt.no/oppskrift/'
df[1] = range(5000, 5000+len(df))
df = df.applymap(str)

# %%
df['url'] = df[0] + df[1]
df1 = df['url']

# %%
def get_url_status(urls):  # checks status for each url in list urls
    
    for url in urls:
        try:
            r = requests.get(url)
            print(url + "\tStatus: " + str(r.status_code))
            urls[]
        except Exception as e:
            print(url + "\tNA FAILED TO CONNECT\t" + str(e))
    return None

# %%
def get_url_status1(urls):
    for url in urls:

# %%
url = 'https://www.godt.no/oppskrift/8900'
r = requests.get(url)
r.status_code
# Out:
# 200

# %%
url_list = df1.values.tolist()
url_list1 = []
url_list2 = []

df_url = pd.DataFrame

# %%
for i in url_list:
    r = requests.get(i)
    url_list2.append(r.status_code)
    print(r.status_code)
# Out:
# 410
# 200
# 410
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 410
# 200
# 200
# 200
# 410
# 200
# 200
# 200
# 410
# 200
# 200
# 410
# 200
# 200
# 410
# 200
# 200
# 200
# 200
# 200
# 410
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 410
# 410
# 200
# 410
# 410
# 200
# 200
# 410
# 200
# 200
# 200
# 200
# 410
# 200
# 410
# 200
# 200
# 200
# 410
# 410
# 200
# 200
# 200
# 410
# 200
# 200
# 200
# 410
# 410
# 200
# 200
# 410
# 410
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 410
# 200
# 410
# 200
# 200
# 200
# 410
# 410
# 200
# 200
# 410
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 410
# 410
# 200
# 410
# 200
# 200
# 200
# 410
# 200
# 200
# 200
# 410
# 200
# 410
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 410
# 200
# 200
# 200
# 200
# 410
# 200
# 200
# 200
# 200
# 200
# 200
# 410
# 410
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 410
# 200
# 200
# 200
# 200
# 410
# 410
# 410
# 410
# 200
# 200
# 200
# 410
# 200
# 200
# 200
# 200
# 200
# 200
# ...

# %%
df_url = pd.DataFrame(url_list2)

# %%
df_url = pd.DataFrame(list(zip(url_list, url_list2)))

# %%
df_url.columns = ['url', 'status_code']

# %%
df_url.to_excel('godt.no_urls.xlsx')

# %%
df_url_active = df_url.loc[df_url['status_code'] == 200]

# %%
df_url_active.to_excel('godt.no_urls_active.xlsx')
