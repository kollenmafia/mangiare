# %%
#Selenium version 4.3.0 
#documentation gets updated frequently it seems like

#Links:
#https://selenium-python.readthedocs.io/index.html

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import pandas as pd

# %%
df = pd.read_excel('matprat_sunn_urls_forscrape.xlsx')

# %%
for url in df['url']:
    options = Options()
    options.add_argument("start-maximized")
    driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)
    driver.get(url)

    ele = driver.find_element(By.XPATH, '//ul[@class="ingredientsList"]')
    try:
        driver.find_element(By.XPATH, '//h3[@class = "ingredient-section-title"]')
        section_title = driver.find_element(By.XPATH, '//h3[@class = "ingredient-section-title"]')
        ele2 = driver.find_element(By.XPATH, '(//ul[@class="ingredientsList"])[2]')
        print(driver.title)
        print(ele.text)
        print(section_title.text)
        print(ele2.text)
    except:
        print(driver.title)
        print(ele.text)
    
driver.close()
# Out:
# Melonsalat | Oppskrift - MatPrat
# ca. 800 g honningmelon
# 2 stk. vårløk
# 1 stk. grønn chili
# 1 håndfull frisk spinat
# 1 stk. lime
# 0,5 potte frisk koriander
#
# Salat med grillet klippfisk | Oppskrift - MatPrat
# ca. 200 g ferdig grillet klippfisk eller annen fisk
# ca. 100 g cherrytomat
# 1 pose ruccula
# 0,5 potte frisk basilikum
# 0,5 potte frisk koriander
# 1 stk. rødløk
# 0,5 bunt bladpersille
# 1 dl valnøttkjerner
# 1 stk. grønn chili
# 2 båter hvitløk
# revet skall av 0,5 stk. sitron
# saft av 0,5 stk. sitron
# 2 ss olivenolje
#
# Grillet makrell med ratatouille - MatPrat
# 2 stk. makrell
# 1 stk. sitron
# 4 stilker friske urter f.eks dill, persille eller estragon
# Ratatouille:
# 2 ss olje
# 1 stk. grønn squash
# 1 stk. aubergine
# 2 stk. rødløk
# 2 stk. paprika , gjerne i ulike farger
# 2 båter hvitløk
# ca. 150 g cherrytomat
# 2 ss rødvinseddik
#
# Klippfisk med grillet ratatouille | Oppskrift - MatPrat
# ca. 800 g godt utvannet klippfisk loin
# Ratatouille:
# ...

# %%
url = ""
options = Options()
options.add_argument("start-maximized")
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)
driver.get(url)

ele = driver.find_element(By.XPATH, '//ul[@class="ingredientsList"]')
try:
    driver.find_element(By.XPATH, '//h3[@class = "ingredient-section-title"]')
    section_title = driver.find_element(By.XPATH, '//h3[@class = "ingredient-section-title"]')
    ele2 = driver.find_element(By.XPATH, '(//ul[@class="ingredientsList"])[2]')
    print(driver.title)
    print(ele.text)
    print(section_title.text)
    print(ele2.text)
except:
    print(driver.title)
    print(ele.text)
driver.close()

# %%
#need to test for 404 errors

# %%
from bs4 import BeautifulSoup
import requests

# %%
url_list = df['url'].values.tolist()
status_code = []

# %%
for i in url_list:
    r = requests.get(i)
    status_code.append(r.status_code)
    print(r.status_code)
# Out:
# 200
# 200
# 404
# 200
# 200
# 404
# 404
# 200
# 404
# 404
# 404
# 200
# 404
# 404
# 404
# 200
# 200
# 200
# 404
# 404
# 200
# 200
# 404
# 200
# 200
# 200
# 200
# 404
# 200
# 200
# 404
# 404
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 404
# 200
# 404
# 200
# 200
# 200
# 200
# 200
# 200
# 404
# 404
# 404
# 404
# 404
# 200
# 200
# 404
# 200
# 200
# 404
# 404
# 200
# 200
# 200
# 404
# 200
# 404
# 200
# 200
# 404
# 200
# 200
# 200
# 200
# 404
# 404
# 404
# 200
# 200
# 404
# 404
# 404
# 404
# 404
# 200
# 404
# 404
# 404
# 404
# 404
# 200
# 404
# 200
# 404
# 404
# 200
# 404
# 200
# 404
# 200
# 200
# 404
# 404
# 200
# 200
# 200
# 200
# 404
# 200
# 200
# 404
# 200
# 404
# 404
# 200
# 200
# 200
# 200
# 404
# 200
# 404
# 404
# 200
# 200
# 200
# 200
# 404
# 404
# 404
# 200
# 200
# 200
# 404
# 200
# 404
# 404
# 404
# 200
# 200
# 200
# 200
# 404
# 404
# 200
# 404
# 404
# 200
# 404
# 200
# 404
# 200
# 404
# 200
# 200
# 404
# 404
# 404
# 200
# 404
# 200
# 404
# 200
# 404
# 200
# 200
# 200
# ...

# %%
df_active_urls = pd.DataFrame(list(zip(url_list, status_code)))
df_active_urls.columns = ['url', 'status_code']
df_active_urls.to_excel('matprat_sunn_status_urls.xlsx')

af_active_urls = df_active_urls.loc[df_active_urls['status_code'] == 200]

# %%
af_active_urls = af_active_urls['url']
af_active_urls.to_excel('matprat_sunn_urls_forscrape.xlsx')
