# %%
#Selenium version 4.3.0 
#documentation gets updated frequently it seems like

#Links:
#https://selenium-python.readthedocs.io/index.html

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

import pandas as pd

# %% [markdown]
# All element in godt.no site:
#
# By xpath:
#
# style _goober
# div application
# path path-1
# div addIngredients
# rect Rectangle-path
# div comments
# div bestDealProductsCarousel
# div relatedCookbooks
# div authorRecipes
# div relatedRecipes
# div modal-root
# script adsScript
# script cogwheelScript
# div gdprAdTransparencyModal
# div gdprAdTransparencyModal__label
# div gdprAdTransparencyModal__closeButton
# a gdprAdTransparencyModal__linksSettings
# a gdprAdTransparencyModal__linkReadMore
# span gdprAdTransparencyModal__creativeId
#
# By CSS selector:
#
# code: driver.find_element(By.CSS_SELECTOR, '*')

# %%
text = []

# %%
url = "https://www.godt.no/oppskrift/8608/dampede-blaaskjell-med-hvitloek"
options = Options()
options.add_argument("start-maximized")
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)
driver.get(url)

ele = driver.find_element(By.ID, "application")

text.append(ele.text)


print(driver.title)
print(ele.text)


driver.close()
# Out:
# Dampede blåskjell med hvitløk | Oppskrift
# OPPSKRIFTER
# ARTIKLER
# INSPIRASJON
# MER
# LOGG INN
# Dampede blåskjell med hvitløk
# 20 min
# 8 varer
# 427
# (0)
# Du trenger ikke mer enn en tørr hvitvin, hvitløk og litt bladpersille for å lage nydelige hvitvinsdampede blåskjell.
# Lise Finckenhagen
# LAGRE I KOKEBOK
# ANNONSE
# Ingredienser
# porsjoner
# 2 kg blåskjell
# 2 - 4 stk hvitløksfedd
# 2 stk sjalottløk, store
# 4 ss olivenolje
# 2 - 3 dl hvitvin, tørr
# 1 dl bladpersille, hakket
# 1 klype tørket chili, (kan sløyfes)
# godt brød, til servering
# LEGG TIL I HANDLELISTEN
# Slik gjør du:
# Behold skjermen på
# Ja
# Nei
# Vask blåskjellene godt i rennende kaldt vann. Kast ødelagte skjell og skjell som ikke lukker seg hvis du "kakker" på dem.
# Finhakk hvitløk og sjalottløk. Varm en romslig gryte, tilsett olje og fres hvitløk og sjalottløk under omrøring til løken er blank og myk.
# ...

# %%
df = pd.DataFrame(text)

# %%
df.to_excel("recipee2.xlsx")

# %%
url = "https://www.godt.no/oppskrift/8119/deilig-og-kremet-fiskesuppe"
options = Options()
options.add_argument("start-maximized")
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)
driver.get(url)

ele = driver.find_element(By.CSS_SELECTOR, 'h1')

ele.text
driver.close()

# %%
title = driver.find_element(By.CLASS_NAME, 'gs gv')
title.get_attribute("innerHTML")
title = driver.find_element(By.XPATH, '/html/body')

# %%
url = "https://www.godt.no/oppskrift/8608/dampede-blaaskjell-med-hvitloek"
options = Options()
options.add_argument("start-maximized")
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)
driver.get(url)

ele = driver.find_element(By.ID, "application")

print(driver.title)
print(ele.text)


driver.close()
