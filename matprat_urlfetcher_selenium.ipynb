# %%
#Selenium version 4.3.0 
#documentation gets updated frequently it seems like

#Links:
#https://selenium-python.readthedocs.io/index.html

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import pandas as pd

# %%
url_list = []

# %%
url = 'https://www.matprat.no/oppskrifter?filtersActive=3&page=14'
options = Options()
options.add_argument("start-maximized")
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)
driver.get(url)

element = driver.find_element(By.XPATH, '//div[@class="cm-list-item__info"]')
element2 = driver.find_element(By.XPATH, '(//div[@class="cm-list-item__info"])[2]')
element3 = driver.find_element(By.XPATH, '(//div[@class="cm-list-item__info"])[3]')
element4 = driver.find_element(By.XPATH, '(//div[@class="cm-list-item__info"])[4]')
element5 = driver.find_element(By.XPATH, '(//div[@class="cm-list-item__info"])[5]')
element6 = driver.find_element(By.XPATH, '(//div[@class="cm-list-item__info"])[6]')
element7 = driver.find_element(By.XPATH, '(//div[@class="cm-list-item__info"])[7]')
element8 = driver.find_element(By.XPATH, '(//div[@class="cm-list-item__info"])[8]')
element9 = driver.find_element(By.XPATH, '(//div[@class="cm-list-item__info"])[9]')
element10 = driver.find_element(By.XPATH, '(//div[@class="cm-list-item__info"])[10]')
element11 = driver.find_element(By.XPATH, '(//div[@class="cm-list-item__info"])[11]')
element12 = driver.find_element(By.XPATH, '(//div[@class="cm-list-item__info"])[12]')
element13 = driver.find_element(By.XPATH, '(//div[@class="cm-list-item__info"])[13]')
element14 = driver.find_element(By.XPATH, '(//div[@class="cm-list-item__info"])[14]')
element15 = driver.find_element(By.XPATH, '(//div[@class="cm-list-item__info"])[15]')
element16 = driver.find_element(By.XPATH, '(//div[@class="cm-list-item__info"])[16]')
element17 = driver.find_element(By.XPATH, '(//div[@class="cm-list-item__info"])[17]')
element18 = driver.find_element(By.XPATH, '(//div[@class="cm-list-item__info"])[18]')
element19 = driver.find_element(By.XPATH, '(//div[@class="cm-list-item__info"])[19]')
element20 = driver.find_element(By.XPATH, '(//div[@class="cm-list-item__info"])[20]')
element21 = driver.find_element(By.XPATH, '(//div[@class="cm-list-item__info"])[21]')
element22 = driver.find_element(By.XPATH, '(//div[@class="cm-list-item__info"])[22]')
element23 = driver.find_element(By.XPATH, '(//div[@class="cm-list-item__info"])[23]')
element24 = driver.find_element(By.XPATH, '(//div[@class="cm-list-item__info"])[24]')
element25 = driver.find_element(By.XPATH, '(//div[@class="cm-list-item__info"])[25]')
element26 = driver.find_element(By.XPATH, '(//div[@class="cm-list-item__info"])[26]')
element27 = driver.find_element(By.XPATH, '(//div[@class="cm-list-item__info"])[27]')
element28 = driver.find_element(By.XPATH, '(//div[@class="cm-list-item__info"])[28]')
element29 = driver.find_element(By.XPATH, '(//div[@class="cm-list-item__info"])[29]')
element30 = driver.find_element(By.XPATH, '(//div[@class="cm-list-item__info"])[30]')



print(element.text)
url_list.append(element.text)

print(element2.text)
url_list.append(element2.text)

print(element3.text)
url_list.append(element3.text)

print(element4.text)
url_list.append(element4.text)

print(element5.text)
url_list.append(element5.text)

print(element6.text)
url_list.append(element6.text)

print(element7.text)
url_list.append(element7.text)

print(element8.text)
url_list.append(element8.text)

print(element9.text)
url_list.append(element9.text)

print(element10.text)
url_list.append(element10.text)

print(element11.text)
url_list.append(element11.text)

print(element12.text)
url_list.append(element12.text)

print(element13.text)
url_list.append(element13.text)

print(element14.text)
url_list.append(element14.text)

print(element15.text)
url_list.append(element15.text)

print(element16.text)
url_list.append(element16.text)

print(element17.text)
url_list.append(element17.text)

print(element18.text)
url_list.append(element18.text)

print(element19.text)
url_list.append(element19.text)

print(element20.text)
url_list.append(element20.text)

print(element21.text)
url_list.append(element21.text)

print(element22.text)
url_list.append(element22.text)

print(element23.text)
url_list.append(element23.text)

print(element24.text)
url_list.append(element24.text)

print(element25.text)
url_list.append(element25.text)

print(element26.text)
url_list.append(element26.text)

url_list.append(element27.text)
print(element27.text)

url_list.append(element28.text)
print(element28.text)

url_list.append(element29.text)
print(element29.text)

url_list.append(element30.text)
print(element30.text)

driver.close()
# Out:
# Denne oppskriften har fått 5 av 5 stjerner.
# Kyllingfilet i grove pitabrød
# Turmat
# Enkel
# Cooktime
# Under 20 min
# Denne oppskriften har fått 0 av 5 stjerner.
# Grillet biffspyd med søtpotet
# Turmat
# Enkel
# Cooktime
# 20–40 min
# Denne oppskriften har fått 0 av 5 stjerner.
# Grillspyd med mangosalat
# Turmat
# Enkel
# Cooktime
# Under 20 min
# Denne oppskriften har fått 0 av 5 stjerner.
# Grillet biff med bakte grønnsaker
# Turmat
# Middels
# Cooktime
# 20–40 min
# Denne oppskriften har fått 5 av 5 stjerner.
# Helgrillet ytrefilet av svin
# Turmat
# Middels
# Cooktime
# Over 60 min
# Denne oppskriften har fått 5 av 5 stjerner.
# Thaigryte med strimlet svinekjøtt
# Turmat
# Enkel
# Cooktime
# 20–40 min
# Denne oppskriften har fått 0 av 5 stjerner.
# Salsabiff med peppercoleslaw
# Turmat
# Enkel
# Cooktime
# 20–40 min
# Denne oppskriften har fått 5 av 5 stjerner.
# Spicy couscoussalat
# Turmat
# Enkel
# Cooktime
# Under 20 min
# Denne oppskriften har fått 4 av 5 stjerner.
# ...

# %%
url_list
# Out:
# ['Denne oppskriften har fått 5 av 5 stjerner.\nMelonsalat\nTurmat\nEnkel\nCooktime\nUnder 20 min',
#  'Denne oppskriften har fått 5 av 5 stjerner.\nSalat med grillet klippfisk\nTurmat\nEnkel\nCooktime\nUnder 20 min',
#  'Denne oppskriften har fått 5 av 5 stjerner.\nGrillet blomkål med gremolata\nTurmat\nMiddels\nCooktime\n20–40 min',
#  'Denne oppskriften har fått 0 av 5 stjerner.\nGrillet makrell med ratatouille\nTurmat\nMiddels\nCooktime\n40–60 min',
#  'Denne oppskriften har fått 0 av 5 stjerner.\nKlippfisk med grillet ratatouille\nTurmat\nMiddels\nCooktime\nOver 60 min',
#  'Denne oppskriften har fått 0 av 5 stjerner.\nGrillet nykål\nTurmat\nEnkel\nCooktime\n20–40 min',
#  'Denne oppskriften har fått 0 av 5 stjerner.\nRatatouille på grillen\nTurmat\nEnkel\nCooktime\n20–40 min',
#  'Denne oppskriften har fått 2 av 5 stjerner.\nMango slush\nTurmat\nSuperenkel\nCooktime\nUnder 20 min',
# ...

# %%
df = pd.DataFrame(url_list)

# %%
df = df.astype(str)

# %%
df.columns = ['body']

# %%
df = df.body.str.split(pat = '\n', expand = True)

# %%
df
# Out:
#                                             body  \
# 0    Denne oppskriften har fått 5 av 5 stjerner.
# 1    Denne oppskriften har fått 5 av 5 stjerner.
# 2    Denne oppskriften har fått 5 av 5 stjerner.
# 3    Denne oppskriften har fått 0 av 5 stjerner.
# 4    Denne oppskriften har fått 0 av 5 stjerner.
# ..                                           ...
# 415  Denne oppskriften har fått 5 av 5 stjerner.
# 416  Denne oppskriften har fått 0 av 5 stjerner.
# 417  Denne oppskriften har fått 4 av 5 stjerner.
# 418  Denne oppskriften har fått 5 av 5 stjerner.
# 419  Denne oppskriften har fått 5 av 5 stjerner.
#
#                                     oppskrift kategori vanskelighetsgrad  \
# 0                                  Melonsalat   Turmat             Enkel
# 1                 Salat med grillet klippfisk   Turmat             Enkel
# 2               Grillet blomkål med gremolata   Turmat           Middels
# 3             Grillet makrell med ratatouille   Turmat           Middels
# ...

# %%
df.columns = ['body', 'oppskrift', 'kategori', 'vanskelighetsgrad', 'beskrivelse', 'tid']
df1 = df['oppskrift']

# %%
df1.to_excel('oppskrifter_matprat_sunn_tittel.xlsx')

# %%
df2 = pd.DataFrame(index=range(420),columns=range(3))

# %%
df1 = df1.str.replace(' ', '-').astype(str)

# %%
df2.columns = ['basic', 'desc', 'url']
df2['basic'] = 'https://www.matprat.no/oppskrifter/sunn/'
df2['desc'] = df1

# %%
df2['url'] = df2['basic'] + df2['desc']

# %%
url_matprat = df2['url']

# %%
url_matprat.to_excel('sunn_url_matprat.xlsx')
